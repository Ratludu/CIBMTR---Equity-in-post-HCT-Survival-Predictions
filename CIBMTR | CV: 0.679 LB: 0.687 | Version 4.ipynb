# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import warnings
warnings.filterwarnings("ignore")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/setuptools-74.1.2-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.features-1.1.1-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/tzdata-2024.1-py2.py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/botocore-1.35.14-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/urllib3-2.2.2-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/jmespath-1.0.1-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/s3transfer-0.10.2-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/pyparsing-3.1.4-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.common-1.1.1-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/idna-3.8-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/six-1.16.0-py2.py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/cycler-0.12.1-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.core-1.1.1-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/networkx-3.3-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/pytz-2024.1-py2.py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/contourpy-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/threadpoolctl-3.5.0-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/boto3-1.35.14-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/certifi-2024.8.30-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/tqdm-4.66.5-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/packaging-24.1-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/requests-2.32.3-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/fonttools-4.53.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/joblib-1.4.2-py3-none-any.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.tabular-1.1.1-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/fonttools-4.55.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/tzdata-2024.2-py2.py3-none-any.whl
# /kaggle/input/pip-install-lifelines/kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl
# /kaggle/input/pip-install-lifelines/contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/pyparsing-3.2.0-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/wrapt-1.17.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/__results__.html
# /kaggle/input/pip-install-lifelines/cycler-0.12.1-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/matplotlib-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/six-1.17.0-py2.py3-none-any.whl
# /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
# /kaggle/input/pip-install-lifelines/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# /kaggle/input/pip-install-lifelines/__notebook__.ipynb
# /kaggle/input/pip-install-lifelines/__output__.json
# /kaggle/input/pip-install-lifelines/typing_extensions-4.12.2-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/pytz-2024.2-py2.py3-none-any.whl
# /kaggle/input/pip-install-lifelines/pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/pip-install-lifelines/packaging-24.2-py3-none-any.whl
# /kaggle/input/pip-install-lifelines/custom.css
# /kaggle/input/equity-post-HCT-survival-predictions/sample_submission.csv
# /kaggle/input/equity-post-HCT-survival-predictions/data_dictionary.csv
# /kaggle/input/equity-post-HCT-survival-predictions/train.csv
# /kaggle/input/equity-post-HCT-survival-predictions/test.csv

# %%
# !pip install /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
# !pip install /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
# !pip install /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
# !pip install /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
# !pip install /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
# !pip install --no-index --find-links /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular autogluon.tabular
# Out:
# Processing /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from autograd==1.7.0) (1.26.4)
# Installing collected packages: autograd
# Successfully installed autograd-1.7.0
# Processing /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: autograd>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from autograd-gamma==0.5.0) (1.7.0)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from autograd-gamma==0.5.0) (1.14.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from autograd>=1.2.0->autograd-gamma==0.5.0) (1.26.4)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=d471cb6e4334319c6dd6334c9677431539cdb9fa0e61fb035be48a0d91dcc2a2
#   Stored in directory: /root/.cache/pip/wheels/6b/b5/e0/4c79e15c0b5f2c15ecf613c720bb20daab20a666eb67135155
# Successfully built autograd-gamma
# Installing collected packages: autograd-gamma
# Successfully installed autograd-gamma-0.5.0
# Processing /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
# Installing collected packages: interface-meta
# Successfully installed interface-meta-1.3.0
# Processing /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
# Requirement already satisfied: interface-meta>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from formulaic==1.0.2) (1.3.0)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.10/site-packages (from formulaic==1.0.2) (1.26.4)
# Requirement already satisfied: pandas>=1.0 in /opt/conda/lib/python3.10/site-packages (from formulaic==1.0.2) (2.2.3)
# Requirement already satisfied: scipy>=1.6 in /opt/conda/lib/python3.10/site-packages (from formulaic==1.0.2) (1.14.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from formulaic==1.0.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /opt/conda/lib/python3.10/site-packages (from formulaic==1.0.2) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0->formulaic==1.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0->formulaic==1.0.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0->formulaic==1.0.2) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->formulaic==1.0.2) (1.16.0)
# Installing collected packages: formulaic
# Successfully installed formulaic-1.0.2
# Processing /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (1.14.1)
# Requirement already satisfied: pandas>=2.1 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (2.2.3)
# Requirement already satisfied: matplotlib>=3.0 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (3.7.5)
# Requirement already satisfied: autograd>=1.5 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (1.7.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /opt/conda/lib/python3.10/site-packages (from lifelines==0.30.0) (1.0.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from formulaic>=0.2.2->lifelines==0.30.0) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from formulaic>=0.2.2->lifelines==0.30.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /opt/conda/lib/python3.10/site-packages (from formulaic>=0.2.2->lifelines==0.30.0) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0->lifelines==0.30.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1->lifelines==0.30.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1->lifelines==0.30.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines==0.30.0) (1.16.0)
# Installing collected packages: lifelines
# Successfully installed lifelines-0.30.0
# Looking in links: /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.tabular-1.1.1-py3-none-any.whl
# Requirement already satisfied: numpy<1.29,>=1.21 in /opt/conda/lib/python3.10/site-packages (from autogluon.tabular) (1.26.4)
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from autogluon.tabular)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from autogluon.tabular) (2.2.3)
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/scikit_learn-1.4.0-1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from autogluon.tabular)
# Requirement already satisfied: networkx<4,>=3.0 in /opt/conda/lib/python3.10/site-packages (from autogluon.tabular) (3.3)
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.core-1.1.1-py3-none-any.whl (from autogluon.tabular)
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.features-1.1.1-py3-none-any.whl (from autogluon.tabular)
# Requirement already satisfied: tqdm<5,>=4.38 in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (4.66.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (2.32.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (3.7.5)
# Requirement already satisfied: boto3<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from autogluon.core==1.1.1->autogluon.tabular) (1.26.100)
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/autogluon.common-1.1.1-py3-none-any.whl (from autogluon.core==1.1.1->autogluon.tabular)
# Requirement already satisfied: psutil<6,>=5.7.3 in /opt/conda/lib/python3.10/site-packages (from autogluon.common==1.1.1->autogluon.core==1.1.1->autogluon.tabular) (5.9.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from autogluon.common==1.1.1->autogluon.core==1.1.1->autogluon.tabular) (70.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<2.3.0,>=2.0.0->autogluon.tabular) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.tabular) (3.5.0)
# INFO: pip is looking at multiple versions of boto3 to determine which version is compatible with other requirements. This could take a while.
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/boto3-1.35.14-py3-none-any.whl (from autogluon.core==1.1.1->autogluon.tabular)
# Requirement already satisfied: botocore<1.36.0,>=1.35.14 in /opt/conda/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.tabular) (1.35.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.tabular) (1.0.1)
# Processing /kaggle/input/autogluon-1-1-1-tabular/autogluon_tabular/s3transfer-0.10.2-py3-none-any.whl (from boto3<2,>=1.10->autogluon.core==1.1.1->autogluon.tabular)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=2.0.0->autogluon.tabular) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autogluon.core==1.1.1->autogluon.tabular) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->autogluon.core==1.1.1->autogluon.tabular) (2024.6.2)
# Installing collected packages: scipy, scikit-learn, s3transfer, boto3, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.6.2
#     Uninstalling s3transfer-0.6.2:
#       Successfully uninstalled s3transfer-0.6.2
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.26.100
#     Uninstalling boto3-1.26.100:
#       Successfully uninstalled boto3-1.26.100
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuml 24.10.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 24.10.0 requires cuvs==24.10.*, which is not installed.
# cuml 24.10.0 requires nvidia-cublas, which is not installed.
# cuml 24.10.0 requires nvidia-cufft, which is not installed.
# cuml 24.10.0 requires nvidia-curand, which is not installed.
# cuml 24.10.0 requires nvidia-cusolver, which is not installed.
# cuml 24.10.0 requires nvidia-cusparse, which is not installed.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.3 which is incompatible.
# cesium 0.12.3 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.10.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# plotnine 0.14.3 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# tsfresh 0.20.3 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.12.0 which is incompatible.
# Successfully installed autogluon.common-1.1.1 autogluon.core-1.1.1 autogluon.features-1.1.1 autogluon.tabular-1.1.1 boto3-1.35.14 s3transfer-0.10.2 scikit-learn-1.4.0 scipy-1.12.0

# %%
from autogluon.tabular import TabularPredictor
from lifelines import KaplanMeierFitter, CoxPHFitter, NelsonAalenFitter
from metric import score
from scipy.stats import rankdata 
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb
from lightgbm import LGBMRegressor,LGBMClassifier
import lightgbm as lgb
from catboost import CatBoostRegressor, CatBoostClassifier
import catboost as cb
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from pathlib import Path
import optuna
import polars as pl

# %%
def stratified_c_index(df, predictions):
    y_true = df[["ID", "efs", "efs_time","race_group"]].copy()
    y_pred = df[["ID"]].copy()
    y_pred["prediction"] = predictions
    m = score(y_true.copy(), y_pred.copy(),"ID")
    return m

# %%
class settings:

    train_link = "/kaggle/input/equity-post-HCT-survival-predictions/train.csv"
    test_link =  "/kaggle/input/equity-post-HCT-survival-predictions/test.csv"
    sub_link = "/kaggle/input/equity-post-HCT-survival-predictions/sample_submission.csv"
    
    seed = 42
    target = 'target'
    n_splits = 10
    col_ignore = ['efs_time','efs','target','ID']

    batch_size = 32768

# %%
class SurvModel:

    def __init__(self, model, n_splits = settings.n_splits, random_state = settings.seed, estimator = 'na'):
        """
        Initialise the SurvModel class

        Parameters:
        - model: A model instance
        - n_splits: Number of folds for k-fold cross validation
        - random_state: for reproducability 
        """

        self.model = model
        self.n_splits = n_splits
        self.random_state = random_state
        self.estimator = estimator
        self.oof = None
        self.pred = None
        self.scores = []
        self.cats = []

    def preprocessing(self, train, test):
        """
        Proprocessing the test and train data

        Parameters
        - train: training dataw
        - test: testing data
        """
        # For now for testing lets use KM estmator
        # Fitted a survival curve to the training data to predict off
        #train['efs_time'] = np.log1p(train['efs_time'])
        if self.estimator == 'km':
            kmf = KaplanMeierFitter()
            kmf.fit(durations = train['efs_time'], event_observed = train['efs'])
            train[settings.target] = kmf.survival_function_at_times(train['efs_time']).values
            train[settings.target] = np.log(train[settings.target])
            print("#"*25,"KM Estmator Fitted", "#"*25)

        elif self.estimator == 'na':
            naf = NelsonAalenFitter()
            naf.fit(durations = train['efs_time'], event_observed = train['efs'])
            train[settings.target] = -naf.cumulative_hazard_at_times(train['efs_time']).values
            print("#"*25,"Nelson-Aalen Estmator Fitted", "#"*25)

        elif self.estimator == 'chris':
                time_col = 'efs_time'
                event_col = 'efs'
                train[settings.target] = train[time_col].values
                mx = train.loc[train[event_col]==1, time_col].max()
                mn = train.loc[train[event_col]==0, time_col].min()
                train.loc[train[event_col]==0, settings.target] = train.loc[train[event_col]==0, settings.target] + mx - mn
                train[settings.target] = train[settings.target].rank()
                train.loc[train[event_col]==0, settings.target] += 1*len(train)
                train[settings.target] = train[settings.target] / train[settings.target].max()
                train[settings.target] = np.log(train[settings.target])
                train[settings.target] -= train[settings.target].mean()
                train[settings.target] *= -1.0

        else:
            train[settings.target] = train.efs_time.copy()
            train.loc[train.efs==0,settings.target]*=-1
            print("#"*25,"CPH Fitted", "#"*25)

        features = [col for col in train.columns if not col in settings.col_ignore]
        
        # Combined test and train to label encode
        combined = pd.concat([train,test], axis = 0, ignore_index = True)

        for col in features:
            if combined[col].dtype == "object":
                self.cats.append(col)
                combined[col] = combined[col].fillna("NAN")
                combined[col],_ = combined[col].factorize()
                combined[col] -= combined[col].min()
                combined[col] = combined[col].astype("int32")
                combined[col] = combined[col].astype("category")

            else:
                if combined[col].dtype=="float64":
                    combined[col] = combined[col].astype("float32")
                if combined[col].dtype=="int64":
                    combined[col] = combined[col].astype("int32")
        train = combined.iloc[:len(train)].copy()
        test = combined.iloc[len(train):].reset_index(drop=True).copy().drop([settings.target,'efs','efs_time'], axis = 1)
        return train, test

    def fit_predict(self, train, test, catboost = False, autogluon = False):
        """
        Fit the model using k-fold cross validation and collect oof predictions.

        Note: the train and test data include ID, efs and efs_time as we need it for the metric.
              We need to remove them for training but add them back in for metric collection.
        
        Parameters:
        - Train: the training data
        - Test: the test data from kaggle

        Returns:
        - OOF predictions
        _ Preditions for the test data
        """
        # Collect features

        features = [col for col in train.columns if not col in settings.col_ignore]
        print("#"*25,"Features","#"*25)
        print(f"There are {len(features)} features.")
        print(features)

        # Initialise k-fold cross validation
        print("#"*25,"Initialise Cross-Validation","#"*25)

        kf = KFold(n_splits = self.n_splits, shuffle=True, random_state=self.random_state)

        # Predictions for OOF and test
        self.oof = np.zeros(len(train))
        self.preds = np.zeros(len(test))

        # Cross-validation loop
        for fold, (train_idx, test_idx) in enumerate(kf.split(train)):
            
            print("#"*25,f"Fold {fold+1}","#"*25)
            # Split data
            x_train, x_val = train.loc[train_idx, features].copy(), train.loc[test_idx, features].copy()
            y_train, y_val = train.loc[train_idx, settings.target].copy(), train.loc[test_idx, settings.target].copy()
            x_test = test[features]

            x_score = train.loc[test_idx,["ID", "efs", "efs_time","race_group"]].copy()
            
            # Train on training set
            if catboost:
                self.model.fit(x_train, y_train, self.cats, verbose = 0, eval_set=[(x_val,y_val)])
            elif autogluon:
                x_train[settings.target] = y_train
                predictor = TabularPredictor(label=settings.target, verbosity =0,  path = "AutogluonModels/CV").fit(x_train, time_limit=60*5)
                
            else:
                self.model.fit(x_train, y_train)

            # Predict on validation set
            if autogluon:
                val_preds = predictor.predict(x_val)
            else:
                val_preds = self.model.predict(x_val)
            self.oof[test_idx] = val_preds

            # Calculate score
            m = stratified_c_index(x_score, val_preds)
            self.scores.append(m)
            print(f"Fold {fold+1}: Stratified C-index: {m}")
            if autogluon:
                self.preds += predictor.predict(x_test)/self.n_splits
            else:
                self.preds += self.model.predict(x_test)/self.n_splits
            
        train_score = train[["ID", "efs", "efs_time","race_group"]].copy()
        print("#"*25,"Cross-Validation Completed","#"*25)
        print(f"Average Stratified C-Index: {np.mean(self.scores)}")
        print(f"Overall Stratified C-Index: {stratified_c_index(train_score, self.oof)}")
        return self.oof, self.preds, np.mean(self.scores)

    def save_predictions(self, filename,train, test):
        """
        Save predictions in a csv.

        Parameters:
        - filename: model_name
        - train: train data for ID
        - test: test data for ID
        """
        directory_train = Path("/kaggle/working/train")
        directory_test = Path("/kaggle/working/test")

        directory_train.mkdir(exist_ok = True)
        print(f"Directory '{directory_train}' created successfully")
        directory_test.mkdir(exist_ok = True)
        print(f"Directory '{directory_test}' created successfully")
            
        
        # oof train preds
        train_csv = train.copy()
        train_csv["prediction"] = self.oof

        train_csv.to_csv("train/"+filename+"_train.csv", index = False)

        # test
        test_csv = test.copy()
        test_csv["prediction"] = self.preds

        test_csv.to_csv("test/"+filename+"_test.csv", index = False)

        print(f"Out of fold predictions and test predictions have been saved")

# %%
class Ensembler:
    def __init__(self, train_folder, test_folder):
        """
        Initialse class with the train and test folders.

        Parameters:
        - train_folder: Path to the train folder containing OOF predictions
        - test_folder: Path to the predictions
        """

        self.train_folder = Path(train_folder)
        self.test_folder = Path(test_folder)
        self.scores = []

    def load_files(self, folder_path):
        """
        Load the train and test files.

        Returns:
        - train: consolidated predictions for each dataset
        - test: consolidated predictions for each dataset
        """
        predictions = {}

        # loop through the csv files
        counter = 0
        for idx, file in enumerate(sorted(folder_path.glob("*.csv"))):
            try:
                df = pd.read_csv(file)
                if "prediction" in df.columns:
                    counter +=1
                    predictions[f"prediction_{counter}"] = df["prediction"].reset_index(drop=True)
                    print(f"Loaded 'prediction' column from {file.name}")
                else:
                    print(f"'prediction' column not found in {file.name}")
            except Exception as e:
                print(f"Error loading {file.name}: {e}")
        if predictions:
            predictions = pd.DataFrame(predictions)
            predictions["ID"] = df['ID']
            return predictions
        else:
            print("No predictions found.")
            return pd.DataFrame()

    def concatenate_train_test(self, train):
        """
        Concatenate train and test folder data into another train and test set.

        Parameters:
        - train: we need this to get the target variable in the training set

        Returns
        - train: Another training set based on the oof predictions.
        - test: Another test set based on preds.
        """
        print(f"Loading predictions from the train folder {self.train_folder}")
        train_predictions = self.load_files(self.train_folder)
        train_predictions[settings.target] = train[settings.target].reset_index(drop=True)

        print(f"Loading predictions from the test folder {self.test_folder}")
        test_predictions = self.load_files(self.test_folder)

        return train_predictions, test_predictions

    def ranking(self, train, test, original_train):
        
        # Collect features

        features = [col for col in train.columns if not col in settings.col_ignore]
        print("#"*25,"Features","#"*25)
        print(f"There are {len(features)} features.")
        print(features)

        # Initialise k-fold cross validation
        print("#"*25,"Initialise Cross-Validation","#"*25)

        kf = KFold(n_splits = settings.n_splits, shuffle=True, random_state=settings.seed)

        # Cross-validation loop
        for fold, (train_idx, test_idx) in enumerate(kf.split(train)):
            
            print("#"*25,f"Fold {fold+1}","#"*25)
            # Split data
            x_train, x_val = train.loc[train_idx, features].copy(), train.loc[test_idx, features].copy()
            y_train, y_val = train.loc[train_idx, settings.target].copy(), train.loc[test_idx, settings.target].copy()
            x_test = test[features]

            x_score = original_train.loc[test_idx,["ID", "efs", "efs_time","race_group"]].copy()

            val_preds = np.zeros(len(x_val))
            
            # Predict on validation set
            for col in x_val:
                if col not in settings.col_ignore:
                    val_preds += rankdata(x_val[col])
                    


            # Calculate score
            m = stratified_c_index(x_score, val_preds)
            self.scores.append(m)
            print(f"Fold {fold+1}: Stratified C-index: {m}")
            
        overall_pred = np.zeros(len(original_train))
        for col in train:
            if col not in settings.col_ignore:
                overall_pred += rankdata(train[col])

        overall_score = original_train[["ID", "efs", "efs_time","race_group"]].copy()
            
        print("#"*25,"Cross-Validation Completed","#"*25)
        print(f"Average Stratified C-Index: {np.mean(self.scores)}")
        print(f"Overall Stratified C-Index: {stratified_c_index(overall_score, overall_pred)}")

# %%
class FE:
    def __init__(self, batch_size):
        self.batch_size = batch_size
        # self.scaler = StandardScaler()

    def load_data(self, path):
        return pl.read_csv(path, batch_size=self.batch_size)

    def recalculate_hla_sums(self, df):     
        df = df.with_columns(
            (pl.col("hla_match_a_low").fill_null(0) + pl.col("hla_match_b_low").fill_null(0) + 
             pl.col("hla_match_drb1_high").fill_null(0)).alias("hla_nmdp_6"),
            
            (pl.col("hla_match_a_low").fill_null(0) + pl.col("hla_match_b_low").fill_null(0) + 
             pl.col("hla_match_drb1_low").fill_null(0)).alias("hla_low_res_6"),
            
            (pl.col("hla_match_a_high").fill_null(0) + pl.col("hla_match_b_high").fill_null(0) + 
             pl.col("hla_match_drb1_high").fill_null(0)).alias("hla_high_res_6"),
            
            (pl.col("hla_match_a_low").fill_null(0) + pl.col("hla_match_b_low").fill_null(0) + 
             pl.col("hla_match_c_low").fill_null(0) + pl.col("hla_match_drb1_low").fill_null(0)
            ).alias("hla_low_res_8"),
            
            (pl.col("hla_match_a_high").fill_null(0) + pl.col("hla_match_b_high").fill_null(0) + 
             pl.col("hla_match_c_high").fill_null(0) + pl.col("hla_match_drb1_high").fill_null(0)
            ).alias("hla_high_res_8"),
            
            (pl.col("hla_match_a_low").fill_null(0) + pl.col("hla_match_b_low").fill_null(0) + 
             pl.col("hla_match_c_low").fill_null(0) + pl.col("hla_match_drb1_low").fill_null(0) +
             pl.col("hla_match_dqb1_low").fill_null(0)).alias("hla_low_res_10"),
            
            (pl.col("hla_match_a_high").fill_null(0) + pl.col("hla_match_b_high").fill_null(0) + 
             pl.col("hla_match_c_high").fill_null(0) + pl.col("hla_match_drb1_high").fill_null(0) +
             pl.col("hla_match_dqb1_high").fill_null(0)).alias("hla_high_res_10"),
        )
        return df

    def cast_datatypes(self, df):
        num_cols = [
            'hla_high_res_8', 'hla_low_res_8', 'hla_high_res_6',
            'hla_low_res_6', 'hla_high_res_10', 'hla_low_res_10',
            'hla_match_dqb1_high', 'hla_match_dqb1_low',
            'hla_match_drb1_high', 'hla_match_drb1_low',
            'hla_nmdp_6', 'year_hct', 'hla_match_a_high',
            'hla_match_a_low', 'hla_match_b_high', 'hla_match_b_low',
            'hla_match_c_high', 'hla_match_c_low', 'donor_age',
            'age_at_hct', 'comorbidity_score', 'karnofsky_score',
            'efs', 'efs_time'
        ]

        for col in df.columns:
            if col in num_cols:
                df = df.with_columns(pl.col(col).fill_null(-1).cast(pl.Float32))  

            else:
                df = df.with_columns(pl.col(col).fill_null('Unknown').cast(pl.String))  

        return df.with_columns(pl.col('ID').cast(pl.Int32))

    def info(self, df):     
        print(f'\nShape of dataframe: {df.shape}')    
        mem = df.memory_usage().sum() / 1024**2
        print('Memory usage: {:.2f} MB\n'.format(mem))
        display(df.head())

    def apply_fe(self, path):
        df = self.load_data(path)
        df = self.recalculate_hla_sums(df)
        df = self.cast_datatypes(df)
        df = df.to_pandas()
        #self.info(df)
        
        cat_cols = [col for col in df.columns if df[col].dtype == pl.String]
        return df, cat_cols

# %% [markdown]
# # Model Training

# %%
estimators = ['km','na','cox','chris']

# %%
lgb_params = {
        'objective': 'regression',
        'min_child_samples': 20,
        'num_iterations': 6000,
        'learning_rate': 0.01,
        'extra_trees': True,
        'reg_lambda': 3.0,
        'reg_alpha': 0.1,
        'num_leaves': 64,
        'metric': 'rmse',
        'max_depth': 10,
        'device': 'cpu',
        'max_bin': 255,
        'verbose': -1,
        'seed': 42
    }

for estimator in estimators:
    if estimator == 'cox':
        pass
    else:

        model = LGBMRegressor(**lgb_params
        )
        
        fe = FE(settings.batch_size)
        train, cat_cols = fe.apply_fe(settings.train_link)
        test, _ = fe.apply_fe(settings.test_link)
        pipeline = SurvModel(model, estimator = estimator)
        df_train, df_test = pipeline.preprocessing(train, test)
        oof_lgb, preds_lgb,_ = pipeline.fit_predict(df_train,df_test)
        pipeline.save_predictions("LightGBM_"+estimator, df_train, df_test)
# Out:
# ######################### KM Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6616963954872367
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6653889717733706
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6594666825831754
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6576925962214946
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6568821395499329
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6622448536130745
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6499369373911472
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6530964165547284
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6497357747262122
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.654230108822842
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6570370876723215
# Overall Stratified C-Index: 0.6637541628100933
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### Nelson-Aalen Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6597195184197939
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6657032181116972
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.659673653804642
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6593423417124012
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6553582911140177
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6644239250918268
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6525292419125841
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6520062707780111
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6491287970264992
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6556923698851982
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6573577627856672
# Overall Stratified C-Index: 0.6641663077431892
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6623749980013179
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6658776623898207
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6495280775725267
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6553073832083794
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.656671769822829
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6615729378756368
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6490534129003082
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.651511634716069
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6472192143560871
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6543192508944476
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6553436341737423
# Overall Stratified C-Index: 0.661785005880592
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved

# %%
for estimator in estimators:
    if estimator == 'cox':
        model = XGBRegressor(
            device="cuda",
            max_depth=3,  
            colsample_bytree=0.5,  
            subsample=0.8,  
            n_estimators=2000,  
            learning_rate=0.02,  
            enable_categorical = True,
            objective = "survival:cox",
            eval_metric = 'cox-nloglik'
        )
        
    else:
        
        model = XGBRegressor(
            device="cuda",
            max_depth=3,  
            colsample_bytree=0.5,  
            subsample=0.8,  
            n_estimators=2000,  
            learning_rate=0.02,  
            enable_categorical=True,
            verbose=0
        )
    
    fe = FE(settings.batch_size)
    train, cat_cols = fe.apply_fe(settings.train_link)
    test, _ = fe.apply_fe(settings.test_link)
    pipeline = SurvModel(model, estimator = estimator)
    df_train, df_test = pipeline.preprocessing(train, test)
    oof_xgb, preds_xgb,_ = pipeline.fit_predict(df_train,df_test)
    pipeline.save_predictions("XGBoost_"+estimator, df_train, df_test)
# Out:
# ######################### KM Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6696745997163387
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6711271274672731
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6785949759069873
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6706507748553334
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6645885522573176
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6736417849180764
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6638193117186837
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6572508188107519
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6566821206047847
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6691320319166443
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.667516209817219
# Overall Stratified C-Index: 0.6751843904248953
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### Nelson-Aalen Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6696745997163387
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6711260561515532
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6787397663517492
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6706492559436802
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6643303842635492
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6736939477215814
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.663820147092408
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.657245847338359
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6566821206047847
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6691320319166443
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6675094157100648
# Overall Stratified C-Index: 0.6752135414003295
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### CPH Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.664681330947301
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6686569248272003
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6712511137352799
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6658740585929229
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6658310945446856
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6737765380128268
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6591399386025637
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6611402637285819
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6541485341458055
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6673537855890065
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6651853582726175
# Overall Stratified C-Index: 0.6714744929232778
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6719429064588168
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6704787924328199
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.67116968459751
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.670723300784745
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6678187501608619
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6734284313223607
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6621571380937121
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6571696430601187
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6549197287947655
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6671345739655455
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6666942949671256
# Overall Stratified C-Index: 0.6734884872032076
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved

# %%
for estimator in estimators:
    if estimator == 'cox':
        model = CatBoostRegressor(loss_function = 'Cox', grow_policy='Lossguide',random_state = settings.seed)
    else:
        model = CatBoostRegressor(task_type = "GPU", grow_policy = 'Lossguide',random_state = settings.seed)

    fe = FE(settings.batch_size)
    train, cat_cols = fe.apply_fe(settings.train_link)
    test, _ = fe.apply_fe(settings.test_link)
    pipeline = SurvModel(model, estimator = estimator)
    df_train, df_test = pipeline.preprocessing(train, test)
    oof_cat, preds_cat,_ = pipeline.fit_predict(df_train,df_test, True)
    pipeline.save_predictions("Catboost_"+estimator, df_train, df_test)
# Out:
# ######################### KM Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6696556947700623
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6702639236224815
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6762629435183758
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6678543992984375
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.66704904987137
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6710635281128848
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6669256185574938
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6558614650945704
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6595494161221596
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6650767544526652
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.66695627934205
# Overall Stratified C-Index: 0.6748693319654783
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### Nelson-Aalen Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6694448918242275
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6673592660020985
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6775485334656859
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6688339766962551
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6682962403903758
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6680861217549603
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6671968204642406
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.656659779267979
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.657004616676225
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.663739137797896
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6664169384339945
# Overall Stratified C-Index: 0.6745747217688207
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### CPH Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6612355975846719
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6717380372046465
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6737016471785621
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6669038094890616
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6656222810634724
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.668593502058756
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.658508959565364
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6578713264339104
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.64993229209033
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6699405526723219
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6644048005341097
# Overall Stratified C-Index: 0.6703382519069385
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6710525809779264
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6711940023453387
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6748931598237641
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6722710032059407
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6667328024155736
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6703990936089258
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6654587974257347
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6514984345044026
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6546967141412827
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6674970189120446
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.6665693607360933
# Overall Stratified C-Index: 0.6731392344427111
# Directory '/kaggle/working/train' created successfully
# Directory '/kaggle/working/test' created successfully
# Out of fold predictions and test predictions have been saved

# %%
for estimator in estimators:
    if estimator == 'cox':
        pass
    else:
        model = None

        fe = FE(settings.batch_size)
        train, cat_cols = fe.apply_fe(settings.train_link)
        test, _ = fe.apply_fe(settings.test_link)
        pipeline = SurvModel(model, estimator = estimator)
        df_train, df_test = pipeline.preprocessing(train, test)
        oof_auto, preds_auto,_ = pipeline.fit_predict(df_train,df_test, False,True)
        pipeline.save_predictions("Autogluon_"+estimator, df_train, df_test)
# Out:
# ######################### KM Estmator Fitted #########################
# ######################### Features #########################
# There are 57 features.
# ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'hla_match_c_high', 'hla_high_res_8', 'tbi_status', 'arrhythmia', 'hla_low_res_6', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'hla_high_res_6', 'cmv_status', 'hla_high_res_10', 'hla_match_dqb1_high', 'tce_imm_match', 'hla_nmdp_6', 'hla_match_c_low', 'rituximab', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'year_hct', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hla_match_a_high', 'hepatic_severe', 'donor_age', 'prior_tumor', 'hla_match_b_low', 'peptic_ulcer', 'age_at_hct', 'hla_match_a_low', 'gvhd_proph', 'rheum_issue', 'sex_match', 'hla_match_b_high', 'race_group', 'comorbidity_score', 'karnofsky_score', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'hla_low_res_8', 'cardiac', 'hla_match_drb1_high', 'pulm_moderate', 'hla_low_res_10']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6664996520048162
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6677745812725163
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6743159549448846
# ######################### Fold 4 #########################

# %% [markdown]
# # Ensembling

# %%
esm = Ensembler("/kaggle/working/train", "/kaggle/working/test")
final_train, final_test = esm.concatenate_train_test(df_train)
esm.ranking(final_train,final_test,df_train)
# Out:
# Loading predictions from the train folder /kaggle/working/train
# Loaded 'prediction' column from Autogluon_chris_train.csv
# Loaded 'prediction' column from Autogluon_km_train.csv
# Loaded 'prediction' column from Autogluon_na_train.csv
# Loaded 'prediction' column from Catboost_chris_train.csv
# Loaded 'prediction' column from Catboost_cox_train.csv
# Loaded 'prediction' column from Catboost_km_train.csv
# Loaded 'prediction' column from Catboost_na_train.csv
# Loaded 'prediction' column from LightGBM_chris_train.csv
# Loaded 'prediction' column from LightGBM_km_train.csv
# Loaded 'prediction' column from LightGBM_na_train.csv
# Loaded 'prediction' column from XGBoost_chris_train.csv
# Loaded 'prediction' column from XGBoost_cox_train.csv
# Loaded 'prediction' column from XGBoost_km_train.csv
# Loaded 'prediction' column from XGBoost_na_train.csv
# Loading predictions from the test folder /kaggle/working/test
# Loaded 'prediction' column from Autogluon_chris_test.csv
# Loaded 'prediction' column from Autogluon_km_test.csv
# Loaded 'prediction' column from Autogluon_na_test.csv
# Loaded 'prediction' column from Catboost_chris_test.csv
# Loaded 'prediction' column from Catboost_cox_test.csv
# Loaded 'prediction' column from Catboost_km_test.csv
# Loaded 'prediction' column from Catboost_na_test.csv
# Loaded 'prediction' column from LightGBM_chris_test.csv
# Loaded 'prediction' column from LightGBM_km_test.csv
# Loaded 'prediction' column from LightGBM_na_test.csv
# Loaded 'prediction' column from XGBoost_chris_test.csv
# Loaded 'prediction' column from XGBoost_cox_test.csv
# Loaded 'prediction' column from XGBoost_km_test.csv
# Loaded 'prediction' column from XGBoost_na_test.csv
# ######################### Features #########################
# There are 14 features.
# ['prediction_1', 'prediction_2', 'prediction_3', 'prediction_4', 'prediction_5', 'prediction_6', 'prediction_7', 'prediction_8', 'prediction_9', 'prediction_10', 'prediction_11', 'prediction_12', 'prediction_13', 'prediction_14']
# ######################### Initialise Cross-Validation #########################
# ######################### Fold 1 #########################
# Fold 1: Stratified C-index: 0.6754133662871165
# ######################### Fold 2 #########################
# Fold 2: Stratified C-index: 0.6769524985195244
# ######################### Fold 3 #########################
# Fold 3: Stratified C-index: 0.6801584025015156
# ######################### Fold 4 #########################
# Fold 4: Stratified C-index: 0.6734423213638173
# ######################### Fold 5 #########################
# Fold 5: Stratified C-index: 0.6708789196800516
# ######################### Fold 6 #########################
# Fold 6: Stratified C-index: 0.6783469786506776
# ######################### Fold 7 #########################
# Fold 7: Stratified C-index: 0.6685902980845415
# ######################### Fold 8 #########################
# Fold 8: Stratified C-index: 0.6624806498633148
# ######################### Fold 9 #########################
# Fold 9: Stratified C-index: 0.6621913024032557
# ######################### Fold 10 #########################
# Fold 10: Stratified C-index: 0.6721829306519357
# ######################### Cross-Validation Completed #########################
# Average Stratified C-Index: 0.672063766800575
# Overall Stratified C-Index: 0.6788536298907514

# %% [markdown]
# # Submission

# %%
final_pred = np.zeros(len(final_test))

for col in final_test.columns:
    if col not in settings.col_ignore:
        final_pred += rankdata(final_test[col])


final_pred
# Out:
# array([28., 42., 14.])

# %%
submission = pd.read_csv(settings.sub_link)
submission['prediction'] = final_pred

submission.to_csv("submission.csv", index = False)
submission
# Out:
#       ID  prediction
# 0  28800        28.0
# 1  28801        42.0
# 2  28802        14.0
